# %%
from langchain_community.llms.ollama import Ollama
from langchain.prompts import ChatPromptTemplate

# %%
# llm = Ollama(model="gemma2:2b")

# %%
import subprocess
import os
# Function to stream output of the subprocess
def stream_output(process):
    for line in process.stdout:
        print(line, end='')  # Output is already a string, so no need to decode

# Function to start Ollama
def start_ollama():
    try:
        # Redirect stdout and stderr to os.devnull
        with open(os.devnull, 'w') as devnull:
            ollama_process = subprocess.Popen(
                ["ollama", "serve"], 
                stdout=devnull,  # Discard stdout
                stderr=devnull,  # Discard stderr
                shell=True       # Required for Windows
            )
            print("Ollama is starting...", flush=True)
            return ollama_process
    except Exception as e:
        print(f"Error starting Ollama: {e}", flush=True)
        return None



# When Backend starts
ollama_process = start_ollama()
# Out:
# Ollama is starting...

# %%
import os
os.getcwd()
# Out:
# 'e:\\CSE299\\chatbot\\rag_tests'

# %%
import json

models = [
    "llama3.2:1b",
    "llama3.2:3b",
    "mistral:latest",
    "llama3.1:latest",
    "gemma2:2b"
]

questions = [
    "What is Newton's first law of motion?",
    "Explain the law of conservation of energy.",
    "What is the difference between velocity and speed?",
    "Define momentum and give an example.",
    "What is the formula for kinetic energy?"
]

# Function to get the model's response to a question
def get_model_answer(model, query):
    return model(query)

results = []

# Loop through models and store answers
for model_name in models:
    print(f"Evaluating Model: {model_name}")
    llm = Ollama(model=model_name)
    
    model_results = {"model": model_name, "answers": {}}
    
    for question in questions:
        answer = get_model_answer(llm, question)
        model_results["answers"][question] = answer
        print(f"Question: {question}")
        print(f"Answer: {answer}")
        print("="*50)
    
    results.append(model_results)

# Save results to a JSON file
with open("model_responses.json", "w") as file:
    json.dump(results, file)
# Out:
# Evaluating Model: llama3.2:1b
# C:\Users\Asus\AppData\Local\Temp\ipykernel_19448\3948529254.py:21: LangChainDeprecationWarning: The method `BaseLLM.__call__` was deprecated in langchain-core 0.1.7 and will be removed in 1.0. Use :meth:`~invoke` instead.
#   return model(query)
# Question: What is Newton's first law of motion?
# Answer: Newton's First Law of Motion, also known as the Law of Inertia, states that "an object at rest will remain at rest, and an object in motion will continue to move with a constant velocity, unless acted upon by an external force." This means that an object will maintain its state of motion unless a force is applied to it, causing it to change its motion.
# ==================================================
# Question: Explain the law of conservation of energy.
# Answer: The law of conservation of energy is a fundamental principle in physics that states that energy cannot be created or destroyed, only converted from one form to another. This means that the total amount of energy remains constant over time, but it can change forms.
#
# In other words, energy is conserved because it is either transferred from one object to another through work (e.g., when you run, your body converts chemical energy into kinetic energy) or transformed from one type of energy to another (e.g., thermal energy, mechanical energy, electrical energy).
#
# Mathematically, this can be represented by the equation:
#
# ΔE = 0
#
# where ΔE is the change in energy, and 0 represents no change.
#
# The law of conservation of energy has several implications, including:
#
# 1. **No energy loss**: Energy cannot be lost to external factors like friction or heat transfer.
# 2. **Energy conversion**: Energy can be converted from one form to another, such as when you cook an egg by converting chemical energy into thermal energy.
# 3. **No creation of new energy**: Energy cannot be created exogenously (from outside the system), only transformed within the system.
#
# Examples of the law of conservation of energy include:
#
# * A car engine converts chemical energy from gasoline into mechanical energy, which propels the vehicle forward.
# * A water heater transfers thermal energy from hot water to cold water.
# * A solar panel converts sunlight into electrical energy, which powers electronic devices.
#
# The law of conservation of energy is a cornerstone of physics and has numerous applications in fields like engineering, chemistry, and biology.
# ==================================================
# Question: What is the difference between velocity and speed?
# Answer: Velocity and speed are often used interchangeably, but they have slightly different meanings.
#
# Speed is a scalar quantity that refers to how fast an object is moving, without considering its direction. It's calculated by dividing the distance traveled by the time taken to travel that distance (e.g., miles per hour or kilometers per hour).
#
# Velocity, on the other hand, is a vector quantity that takes into account both the speed and direction of an object's motion. It's calculated by adding the speed of the object to its direction of motion (e.g., meters per second with direction).
#
# To illustrate the difference:
#
# * Speed: If you're traveling at 60 miles per hour east, your speed is 60 mph.
# * Velocity: If you're also traveling north at 30 miles per hour, your velocity would be 90 mph (60 + 30), because it includes both the speed and direction of your motion.
#
# In everyday language, many people use "speed" to refer to velocity, especially when talking about cars or other objects moving quickly. However, technically speaking, speed is a scalar quantity, while velocity is a vector quantity.
#
# Here's an example to help you understand the difference:
#
# Imagine driving on the highway at 60 miles per hour. You're not necessarily going any faster (your speed remains the same), but you are moving in a certain direction (east). Your velocity would be 60 mph east, because it includes both your speed and direction.
#
# In contrast, if you have a bike that's traveling uphill at 15 miles per hour north, your speed is still 15 mph. However, your velocity would only be 30 mph (15 + 15), because the motion is confined to one direction (north).
#
# I hope this helps clarify the difference between speed and velocity!
# ==================================================
# Question: Define momentum and give an example.
# Answer: Momentum is a fundamental concept in physics that describes the tendency of an object to continue moving in a straight line at a constant velocity, or when changing direction. It's a measure of an object's mass and velocity combined.
#
# In simple terms, momentum (p) is calculated as the product of an object's mass (m) and its velocity (v), i.e., p = m × v.
#
# For example, imagine two friends, Alex and Ben, sitting on a park bench. They both have the same mass (10 kg each) and are initially moving in opposite directions, one going to their right and the other to their left.
#
# When they're both stopped at the bench, they'll maintain their velocity unless acted upon by an external force. This means that Alex and Ben will continue to move in a straight line with the same velocity (10 m/s) until something slows them down or stops them altogether.
#
# So, in this example, the momentum of each friend is equal (10 kg × 10 m/s = 100 kg·m/s). However, because they're moving in opposite directions, their individual momenta add up to zero.
# ==================================================
# Question: What is the formula for kinetic energy?
# Answer: The formula for kinetic energy is K = (1/2)mv^2, where:
#
# * K is the kinetic energy
# * m is the mass of the object
# * v is the velocity of the object
# ==================================================
# Evaluating Model: llama3.2:3b
# Question: What is Newton's first law of motion?
# Answer: Newton's First Law of Motion, also known as the Law of Inertia, states that:
#
# "An object at rest will remain at rest, and an object in motion will continue to move with a constant velocity, unless acted upon by an external force."
#
# In other words, an object will maintain its state of motion (either moving or not moving) until a force is applied to it. This law describes the tendency of objects to resist changes in their motion.
#
# For example:
#
# * A car will keep moving at a constant speed if no brakes are pressed.
# * A ball will continue rolling on a smooth surface unless friction slows it down.
# * An object dropped from rest will fall straight down, accelerating towards the ground until gravity's force stops its motion.
#
# Newton's First Law is often represented mathematically as F = 0, where F is the net force acting on an object and 0 is zero. This law has numerous applications in physics, engineering, and other fields.
# ==================================================
# Question: Explain the law of conservation of energy.
# Answer: The law of conservation of energy states that energy cannot be created or destroyed, only converted from one form to another. In other words, the total energy of an isolated system remains constant over time.
#
# Mathematically, this can be expressed as:
#
# Energy (E) = ΔE / dt = 0
#
# Where ΔE/dt is the rate of change of energy, and E represents the total energy of the system.
#
# The law of conservation of energy applies to all forms of energy, including:
#
# 1. Kinetic energy (the energy of motion)
# 2. Potential energy (stored energy, such as gravitational or elastic potential)
# 3. Thermal energy (the energy of heat)
# 4. Electrical energy
# 5. Chemical energy (the energy stored in chemical bonds)
#
# The law is often illustrated using the following equation:
#
# E1 + ΔE = E2
#
# Where E1 and E2 are the initial and final energies, respectively, and ΔE represents the change in energy.
#
# Some key points to note about the law of conservation of energy include:
#
# * Energy can be converted from one form to another, but it cannot be created or destroyed.
# * The total energy of an isolated system remains constant over time.
# * The law applies to all forms of energy, regardless of their source or destination.
# * Energy can be transferred from one location to another, but the total amount of energy remains the same.
#
# Examples of the law in action include:
#
# * A car engine converts chemical energy into kinetic energy, propelling the car forward.
# * A battery stores electrical energy and releases it as light when connected to a circuit.
# * A pot of boiling water transfers thermal energy to the surrounding environment.
#
# In conclusion, the law of conservation of energy is a fundamental principle that describes how energy behaves in the universe. It states that energy cannot be created or destroyed, only converted from one form to another, and applies to all forms of energy.
# ==================================================
# Question: What is the difference between velocity and speed?
# Answer: Velocity and speed are often used interchangeably, but they have distinct meanings in physics.
#
# Speed refers to the magnitude of an object's movement, measured in units of distance per unit time (e.g., meters per second). It describes how fast an object is moving, but it doesn't take into account the direction of the motion. For example, a car traveling north at 60 km/h has a speed of 60 km/h, regardless of whether it's turning left or right.
#
# Velocity, on the other hand, is the rate of change of an object's position with respect to time, measured in units of distance per unit time (e.g., meters per second). It takes into account both the magnitude and direction of an object's movement. A positive velocity indicates motion in a specific direction, while a negative velocity indicates motion in the opposite direction.
#
# To illustrate the difference, consider this example:
#
# * A car traveling north at 60 km/h has a speed of 60 km/h.
# * The same car traveling east at 60 km/h would have a different speed (eastward motion) and also a different velocity (eastward motion with a specific speed).
#
# In summary:
#
# Speed: magnitude of movement
# Velocity: rate of change of position with respect to time, including direction
#
# Both speed and velocity are essential concepts in physics, and understanding the difference between them is crucial for analyzing and describing the motion of objects.
# ==================================================
# Question: Define momentum and give an example.
# Answer: Momentum is the product of an object's mass and velocity. It is a measure of the amount of motion an object has, and it plays a crucial role in physics, particularly in collisions and projectile motion.
#
# The formula for calculating momentum is:
#
# Momentum (p) = Mass (m) x Velocity (v)
#
# p = m x v
#
# For example, imagine two billiard balls colliding with each other. Ball A has a mass of 5 kg and an initial velocity of 10 m/s, while ball B has a mass of 3 kg and an initial velocity of -15 m/s.
#
# In this scenario, the momentum of ball A is:
#
# p_A = m_A x v_A = 5 kg x 10 m/s = 50 kg m/s
#
# The momentum of ball B is:
#
# p_B = m_B x v_B = 3 kg x (-15 m/s) = -45 kg m/s
#
# Since momentum is a vector quantity, it has both magnitude and direction. The negative sign indicates that the velocity of ball B is in the opposite direction to that of ball A.
#
# After the collision, if ball A gains some of ball B's momentum, the total momentum will remain conserved, meaning it remains the same before and after the collision. This conservation of momentum is a fundamental principle in physics.
# ==================================================
# Question: What is the formula for kinetic energy?
# Answer: The formula for kinetic energy is:
#
# Kinetic Energy (KE) = (1/2) × mass (m) × velocity (v)²
#
# Mathematically, it can be represented as:
#
# KE = (1/2)mv²
#
# Where:
#
# * KE is the kinetic energy
# * m is the mass of the object
# * v is the velocity of the object
# ==================================================
# Evaluating Model: mistral:latest
# Question: What is Newton's first law of motion?
# Answer:  Newton's First Law of Motion, also known as the Law of Inertia, states that an object at rest will stay at rest and an object in motion will continue to move at a constant velocity in a straight line unless acted upon by an unbalanced force. This means that an object tends to maintain its state of motion or rest without any external intervention. It is one of the three fundamental laws of motion, along with Newton's Second Law (F=ma) and Third Law (action-reaction).
# ==================================================
# Question: Explain the law of conservation of energy.
# Answer:  The Law of Conservation of Energy is a fundamental principle in physics, which states that energy cannot be created or destroyed, but it can be transformed from one form to another. This means that the total amount of energy in an isolated system remains constant over time.
#
# The law applies to all types of energy, including mechanical, electrical, thermal, chemical, light, and nuclear energy. Here's a simple breakdown:
#
# 1. Mechanical Energy: Energy associated with the motion or position of objects, such as kinetic (motion) and potential (stored) energy.
# 2. Electrical Energy: Energy related to moving electric charges, as in electric current.
# 3. Thermal Energy: Energy due to the movement of particles, which results in heat.
# 4. Chemical Energy: Energy stored in the chemical bonds of a substance. When a reaction occurs, that energy is released or absorbed.
# 5. Light Energy: Energy carried by electromagnetic waves, such as visible light, X-rays, and radio waves.
# 6. Nuclear Energy: Energy associated with the interactions of atomic nuclei, including fusion and fission processes.
#
# In practical terms, this law means that when energy is used in one form (for example, electrical energy to power a device), it comes from another source (like chemical energy stored in batteries). The total amount of energy remains constant during the transformation process, but its form may change. This principle has significant implications for understanding and predicting various physical phenomena and designing technological systems.
# ==================================================
# Question: What is the difference between velocity and speed?
# Answer:  Velocity and speed are related concepts in physics, but they have distinct differences:
#
# 1. Speed refers to the magnitude (or rate) at which an object is moving in a given direction. It is a scalar quantity, meaning it has only magnitude and no direction. For example, if a car is traveling 60 miles per hour on a straight road, its speed is 60 mph regardless of the direction it's heading.
#
# 2. Velocity, on the other hand, describes both the speed and the direction of an object's motion. It is a vector quantity, meaning it has both magnitude and direction. For instance, if that same car is moving 60 mph northward, its velocity would be 60 m/s (or 38 mph) in the north direction.
#
# In summary, speed focuses on the rate at which an object is moving without considering its direction, while velocity considers both the magnitude and direction of an object's motion.
# ==================================================
# Question: Define momentum and give an example.
# Answer:  Momentum is a fundamental concept in physics that describes the motion of an object. It quantifies both the magnitude and direction of the object's movement. Momentum is calculated by multiplying the mass of the object by its velocity (speed in a given direction). The SI unit for momentum is kg*m/s.
#
# The formula for momentum is: p = m * v, where p is momentum, m is mass, and v is velocity.
#
# A simple example to illustrate this concept could be a bowling ball rolling down a ramp towards a stationary pin. If we assume that the bowling ball has a mass of 6 kg and is moving with a speed of 5 m/s, we can calculate its momentum: p = m * v = 6 kg * 5 m/s = 30 kg*m/s.
#
# In this scenario, the bowling ball would have 30 units of momentum moving in the direction of the ramp towards the pin. When it collides with the pin, the momentum is transferred to the pin, causing it to move away from the impact point. The principle of conservation of momentum states that the total momentum before a collision is equal to the total momentum after the collision, as long as there are no external forces acting upon the system. This helps explain how the bowling ball can cause the pins to spread out after being hit.
# ==================================================
# Question: What is the formula for kinetic energy?
# Answer:  The formula for kinetic energy (KE) is:
#
# KE = 1/2 \* m \* v^2
#
# Where:
# - KE is the kinetic energy,
# - m is the mass of an object, and
# - v is the velocity of the object.
#
# The kinetic energy represents the energy an object possesses due to its motion. It is proportional to the square of the velocity. In SI units, the unit of kinetic energy is joules (J).
# ==================================================
# Evaluating Model: llama3.1:latest
# Question: What is Newton's first law of motion?
# Answer: Newton's First Law of Motion, also known as the Law of Inertia, states that:
#
# **An object at rest will remain at rest, and an object in motion will continue to move with a constant velocity, unless acted upon by an external force.**
#
# In other words, if there is no net force applied to an object, it will maintain its state of motion or rest.
#
# This law was first described by Sir Isaac Newton in his work "Philosophiæ Naturalis Principia Mathematica" (Mathematical Principles of Natural Philosophy) in 1687.
#
# To illustrate this concept:
#
# * A ball on a flat surface will continue to roll with the same speed and direction unless friction or another external force slows it down or changes its path.
# * An object sitting still on the ground will remain at rest, unless an external force (such as a push or pull) is applied to it.
#
# The First Law of Motion emphasizes that an object's state of motion is not affected by any internal forces within itself, but only by external forces acting upon it.
# ==================================================
# Question: Explain the law of conservation of energy.
# Answer: One of the most fundamental laws in physics!
#
# The law of conservation of energy states that:
#
# **Energy cannot be created or destroyed, only converted from one form to another.**
#
# In other words, the total energy of a closed system remains constant over time. Energy can change forms, such as from kinetic (movement) energy to potential (stored) energy, or from thermal energy (heat) to mechanical energy (work). However, the total amount of energy within the system always remains the same.
#
# This law applies to all forms of energy:
#
# 1. **Kinetic energy** (the energy of motion): e.g., a rolling ball's kinetic energy decreases as its speed slows down.
# 2. **Potential energy** (stored energy): e.g., water stored in a reservoir has potential energy, which is converted into kinetic energy when it flows out.
# 3. **Thermal energy** (heat): e.g., the heat from a fire can be used to warm up a room or melt ice.
# 4. **Mechanical energy** (work): e.g., the work done by a person lifting an object converts chemical energy in their muscles into mechanical energy.
#
# Examples of conservation of energy:
#
# * A ball rolls down a hill, converting potential energy (due to its height) into kinetic energy (its speed).
# * A car's engine burns gasoline, converting chemical energy from fuel into thermal energy (heat), which is then converted into kinetic energy (the car's motion).
# * A waterwheel converts the kinetic energy of flowing water into mechanical energy, which powers a mill.
# * A solar panel converts sunlight's thermal energy into electrical energy.
#
# The law of conservation of energy was first proposed by Julius Robert Mayer in 1842 and later formulated more precisely by Hermann von Helmholtz. It has since been widely applied to understand various physical phenomena, from the behavior of atoms to the workings of complex machines.
#
# Remember: Energy cannot be created or destroyed, only converted!
# ==================================================
# Question: What is the difference between velocity and speed?
# Answer: Velocity and speed are two related but distinct physical quantities. The key difference between them lies in their relationship to time.
#
# **Speed**: Speed is a scalar quantity that refers to how fast an object is moving, without considering its direction. It's a measure of the rate at which an object covers distance. In other words, speed is the magnitude (amount) of motion, but not its orientation.
#
# Example: If you're driving 60 miles per hour north on the highway, your speed is 60 mph.
#
# **Velocity**: Velocity, on the other hand, is a vector quantity that includes both the speed and direction of an object's movement. It's a measure of the rate at which an object covers distance in a specific direction. Velocity takes into account not only how fast you're moving (speed) but also where you're headed.
#
# Example: If you're driving 60 miles per hour north on the highway, your velocity is 60 mph north.
#
# To illustrate the difference:
#
# * Speed is like asking how many steps you took in a day.
# * Velocity is like asking which direction you walked and how fast (e.g., "I walked 10 kilometers northwest at a moderate pace").
#
# In summary, speed measures how quickly an object moves, while velocity takes into account both the speed and direction of movement.
#
# Here are some key implications:
#
# 1. **Positive/negative values**: Velocity can be positive or negative, depending on its direction (e.g., north or south).
# 2. **Magnitude vs. magnitude with direction**: Speed is a scalar value, whereas velocity is a vector quantity that includes both the speed and direction.
# 3. **Units of measurement**: While speed and velocity have the same units (e.g., miles per hour), they're measured differently.
#
# Now, go forth and impress your friends with your newfound understanding of this fundamental distinction!
# ==================================================
# Question: Define momentum and give an example.
# Answer: Momentum is the product of a body's mass and velocity. It is denoted by "p". The formula for calculating momentum is given as:
#
# P = m × v
#
# Where,
# m = Mass of the body
# v = Velocity of the body
#
# Example:
# A cricket ball weighing 0.15 kg is traveling at a speed of 40 ms-1. We can calculate its momentum using the above formula.
#
# p = m × v
# = (0.15) × 40
# = 6 kgms-1
# ==================================================
# Question: What is the formula for kinetic energy?
# Answer: The formula for kinetic energy is:
#
# **Kinetic Energy (KE) = ½ × **mass** × velocity²**
#
# Mathematically, this can be represented as:
#
# KE = ½mv²
#
# Where:
# - KE is the kinetic energy
# - m is the mass of an object
# - v is the velocity (speed) of the object
# ==================================================
# Evaluating Model: gemma2:2b
# Question: What is Newton's first law of motion?
# Answer: Newton's First Law of Motion, also known as the **law of inertia**, states:
#
# **An object at rest will stay at rest, and an object in motion will stay in motion with the same speed and in the same direction unless acted upon by an unbalanced force.**
#
# Here's a breakdown:
#
# * **Inertia:**  This is the tendency of an object to resist changes in its motion.
# * **At Rest/In Motion:** This refers to objects that are stationary or moving at a constant velocity (speed and direction).
# * **Unbalanced Force:**  Any force that acts upon an object will cause it to change its state of rest or motion (acceleration).
#
# **Key Points:**
#
# * The law applies whether the object is experiencing no forces (static) or only forces from other objects are acting on it (kinetic).
# * It explains why a ball thrown upwards slows down and eventually stops before falling back down.
#
#
# Let me know if you'd like examples to illustrate this law!
#
# ==================================================
# Question: Explain the law of conservation of energy.
# Answer: ## The Law of Conservation of Energy: No Magic, Just Transfer!
#
# This is a fundamental principle in physics that states **energy can neither be created nor destroyed, only transformed from one form to another**.  Think of it like this:
#
# * You can't have more energy in the universe than there is.
# * But you can change how that energy looks and feels!
#
# **Here's a breakdown:**
#
# * **Energy Types:** This isn't just about "energy" itself, but different forms of it. Think of:
#     * **Kinetic Energy:**  Movement (like a moving car)
#     * **Potential Energy:** Stored energy (like a stretched rubber band)
#     * **Thermal Energy:** Heat (like hot water)
#     * **Light Energy:** Light waves (like sunlight)
#     * **Chemical Energy:** Fuel for chemical reactions (like food)
# * **Transformation:**  Energy doesn't just disappear; it changes. A rolling ball on the floor has kinetic energy, but when that ball hits a wall, some of its energy is transferred into sound and potential energy due to deformation.
# * **Conservation:** The total amount of energy in a system remains constant. Even though the form may change, you can't magically make more or less energy.
#
# **Example:**
#
# Imagine dropping a rock from a cliff:
#
# 1. **Potential Energy (PE):**  The rock has potential energy due to its height.
# 2. **Kinetic Energy (KE):** As it falls, the rock gains kinetic energy as it gains speed and moves.
# 3. **Transfer of Energy:** The rock doesn't just disappear.  It hits the ground and transfers that kinetic energy to the ground (causing damage), some might be lost in air resistance, and the rock itself has its potential energy transformed into other forms like heat.
#
#
# **Why is it important?**
#
# The law of conservation of energy helps us understand:
#
# * **The world's systems:** Why things happen and why they work.
# * **Technological progress:** How to design more efficient machines (like solar panels or electric cars).
# * **Energy resources:**  How we can use them sustainably.
#
#
# Let me know if you'd like to dive deeper into any specific aspect of the law!
#
# ==================================================
# Question: What is the difference between velocity and speed?
# Answer: Here's the breakdown of the differences between velocity and speed:
#
# **Speed**
#
# * **Definition:** How fast an object is moving. It only tells you the rate at which the object changes its position (distance).
# * **Units:** Meters per second (m/s), kilometers per hour (km/h), etc.
# * **Example:** A car traveling at 60 mph.
#
# **Velocity**
#
# * **Definition:**  Both speed and direction are included in velocity. It tells you how fast an object is moving *and* the path it's taking.
# * **Units:** Meters per second (m/s), kilometers per hour (km/h), etc., along with a direction (e.g., North, South, East, West).
# * **Example:**  A car traveling at 60 mph due east.
#
#
# **In short:**
#
# * **Speed** is just *how fast* an object is moving.
# * **Velocity** is both *how fast* and *in what direction* an object is moving.
#
# **Think of it this way:**
#
# * Speed is like the car's engine speed, while velocity is like the car's overall movement (speed + direction).
#
#
# Let me know if you'd like more examples!
#
# ==================================================
# Question: Define momentum and give an example.
# Answer: ##  Momentum Defined:
#
# **Momentum** is a measure of how much **motion** an object possesses. It's defined as the product of an object's **mass** (how much matter it has) and its **velocity** (how fast it's moving).
#
# **Equation:**
#
# Momentum (p) = Mass (m) * Velocity (v)
#
# **Units:**  Newton-meters per second (N·m/s) or kg·m/s
#
#
# ## Example:
#
# Let's say you have a **bowling ball** with a mass of **7.2 kilograms**. If it's rolling at a speed of **10 meters per second**, its momentum would be:
#
# p = m * v
# p = (7.2 kg) * (10 m/s)
# p = 72 kg·m/s
#
#
# **Explanation:** The bowling ball has a large mass and moves at a considerable speed, resulting in a high momentum.  This means that the bowling ball would have significant force needed to stop or change its direction.
#
#
# ## Key Points:
#
# * **Momentum is directly proportional to both mass and velocity.** A more massive object will have more momentum for the same velocity, while an object traveling faster will have greater momentum than a slower-moving object with the same mass.
# * **The magnitude of momentum indicates the force required to change its motion:**  Objects with higher momentum require more force to stop them or change their direction.
#
#
# Let me know if you have any other questions about momentum!
# ==================================================
# Question: What is the formula for kinetic energy?
# Answer: The formula for kinetic energy is:
#
# **KE = (1/2) * m * v²**
#
# where:
#
# * **KE** represents kinetic energy (measured in Joules)
# * **m** represents mass (measured in kilograms)
# * **v** represents velocity (measured in meters per second)
#
#
# This formula indicates that the kinetic energy of an object is directly proportional to its mass and the square of its velocity.
#
# Let me know if you'd like more explanation or have other physics questions! 😊
#
# ==================================================

# %%
import time

def measure_inference_time(model, query):
    start_time = time.time()
    response = model.invoke(query)  # Replace with actual generation method
    end_time = time.time()
    return end_time - start_time

# %%
# List of models
models = [
    "llama3.2:1b",
    "llama3.2:3b",
    "mistral:latest",
    "llama3.1:latest",
    "gemma2:2b"
]

query = "Explain Newton's first law with an example."

# Loop through the models and measure inference time for each
for model_name in models:
    llm = Ollama(model=model_name)
    time_taken = measure_inference_time(llm, query)
    print(f"Model: {model_name}, Inference Time: {time_taken:.2f} seconds")
# Out:
# Model: llama3.2:1b, Inference Time: 14.13 seconds
# Model: llama3.2:3b, Inference Time: 17.28 seconds
# Model: mistral:latest, Inference Time: 90.12 seconds
# Model: llama3.1:latest, Inference Time: 143.50 seconds
# Model: gemma2:2b, Inference Time: 19.56 seconds

# %%
import torch

# Check if CUDA (GPU) is available
if torch.cuda.is_available():
    print("GPU is available: ", torch.cuda.get_device_name(0))
else:
    print("GPU is not available, using CPU.")
# Out:
# GPU is not available, using CPU.

# %%
pip install psutil
# Out:
# Requirement already satisfied: psutil in e:\cse299\chatbot\venv\lib\site-packages (6.0.0)Note: you may need to restart the kernel to use updated packages.

# %%
import psutil
import time


# Function to get memory usage in GB
def get_memory_usage():
    process = psutil.Process()  # Get the current process
    memory_usage = process.memory_info().rss / (1024 ** 3)  # Convert to GB
    return memory_usage

# List of models
models = [
    "llama3.2:1b",
    "llama3.2:3b",
    "mistral:latest",
    "llama3.1:latest",
    "gemma2:2b"
]

query = "Explain Newton's first law with an example."

# Loop through the models and measure memory usage for each
for model_name in models:
    print(f"Loading model: {model_name}")
    
    # Load the model
    llm = Ollama(model=model_name)
    
    # Wait for model loading (optional, adjust as needed)
    time.sleep(2)  # Give the model some time to load and initialize
    
    # Get memory usage after loading the model
    memory_after_loading = get_memory_usage()
    
    # Run the inference
    print("Running inference...")
    llm(query)
    
    # Get memory usage after inference
    memory_after_inference = get_memory_usage()
    
    # Calculate the memory usage during inference
    memory_used = memory_after_inference - memory_after_loading
    
    print(f"Model: {model_name}")
    print(f"Memory Usage during inference: {memory_used:.2f} GB")
    print("-" * 50)
# Out:
# Loading model: llama3.2:1b
# Running inference...
# Model: llama3.2:1b
# Memory Usage during inference: 0.00 GB
# --------------------------------------------------
# Loading model: llama3.2:3b
# Running inference...
# Model: llama3.2:3b
# Memory Usage during inference: 0.00 GB
# --------------------------------------------------
# Loading model: mistral:latest
# Running inference...
# Model: mistral:latest
# Memory Usage during inference: 0.00 GB
# --------------------------------------------------
# Loading model: llama3.1:latest
# Running inference...
# Model: llama3.1:latest
# Memory Usage during inference: 0.00 GB
# --------------------------------------------------
# Loading model: gemma2:2b
# Running inference...
# Model: gemma2:2b
# Memory Usage during inference: 0.00 GB
# --------------------------------------------------

# %%
pip install memory-profiler
# Out:
# Collecting memory-profilerNote: you may need to restart the kernel to use updated packages.
#
#   Downloading memory_profiler-0.61.0-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: psutil in e:\cse299\chatbot\venv\lib\site-packages (from memory-profiler) (6.0.0)
# Downloading memory_profiler-0.61.0-py3-none-any.whl (31 kB)
# Installing collected packages: memory-profiler
# Successfully installed memory-profiler-0.61.0

# %%
from memory_profiler import memory_usage

def get_model_memory_usage():
    # Load the model and run inference
    llm = Ollama(model="llama3.2:1b")
    time.sleep(2)
    result = llm("Explain Newton's first law with an example.")
    
    return result

# Measure memory usage of the function
mem_usage = memory_usage(get_model_memory_usage)
print(f"Memory usage during model inference: {max(mem_usage) - min(mem_usage):.2f} MiB")
# Out:
# Memory usage during model inference: 0.01 MiB

# %%
import os
from time import time
from memory_profiler import memory_usage
# from ollama import Ollama

# List of models
models = [
    "llama3.2:1b",
    "llama3.2:3b",
    "mistral:latest",
    "llama3.1:latest",
    "gemma2:2b"
]

query = "Explain Newton's first law with an example."

def measure_memory_usage():
    """Returns current memory usage in MB."""
    process = psutil.Process(os.getpid())
    return process.memory_info().rss / (1024 ** 2)  # Memory in MB

def run_inference(model_name, query):
    """Load model, run inference, and measure memory usage."""
    llm = Ollama(model=model_name)
    
    # Measure memory usage before loading the model
    memory_before = measure_memory_usage()
    
    # Perform inference
    start_time = time()
    response = llm(query)  # Perform the inference with the model
    inference_time = time() - start_time
    
    # Measure memory usage after inference
    memory_after_inference = measure_memory_usage()
    
    return memory_before, memory_after_inference, inference_time, response

# Loop through the models
for model_name in models:
    print(f"Model: {model_name}")
    
    memory_before, memory_after_inference, inference_time, response = run_inference(model_name, query)
    
    print(f"Memory before loading: {memory_before:.2f} MB")
    print(f"Memory after inference: {memory_after_inference:.2f} MB")
    print(f"Memory used during inference: {memory_after_inference - memory_before:.2f} MB")
    print(f"Inference Time: {inference_time:.2f} seconds")
    print(f"Response: {response}\n")
# Out:
# Model: llama3.2:1b
# Memory before loading: 274.02 MB
# Memory after inference: 274.02 MB
# Memory used during inference: 0.00 MB
# Inference Time: 15.35 seconds
# Response: Newton's first law of motion, also known as the Law of Inertia, states that an object at rest will remain at rest, and an object in motion will continue to move with a constant velocity, unless acted upon by an external force.
#
# Let's consider an example to illustrate this concept.
#
# **Example: A Rolling Ball**
#
# Imagine you have a ball that is rolling across the floor. Initially, it comes to a stop when it hits the ground. At first glance, it might seem like the ball will keep rolling indefinitely without any change in its state of motion.
#
# However, if you try to push or pull the ball, something interesting happens. Despite your efforts, the ball continues to roll forward at a constant speed, assuming there are no external forces acting upon it.
#
# This is an example of Newton's first law in action. The ball has a natural tendency to maintain its state of motion, and any changes in this state require an external force to be applied.
#
# **Why does the ball keep rolling?**
#
# The key factor behind the ball's continued motion is inertia. According to Newton's second law of motion (F = ma), an object at rest will remain at rest unless an external force acts upon it. In this case, the ball has more mass than air resistance or friction, so there is no net external force acting on it to slow it down.
#
# Additionally, the force of gravity acting on the ball is balanced by its weight, which also helps to maintain its motion. The ball's velocity remains constant because the forces opposing its motion (gravity and inertia) are in equilibrium.
#
# **Conclusion**
#
# Newton's first law explains why an object will continue to move with a constant velocity unless acted upon by an external force. In the example of the rolling ball, we see that the ball's natural tendency to maintain its state of motion is what keeps it moving at a constant speed until an external force (like pushing or pulling) intervenes and changes its motion.
#
# I hope this example helps to clarify Newton's first law!
#
# Model: llama3.2:3b
# Memory before loading: 274.02 MB
# Memory after inference: 274.02 MB
# Memory used during inference: 0.00 MB
# Inference Time: 18.79 seconds
# Response: Newton's First Law, also known as the Law of Inertia, states that:
#
# "An object at rest will remain at rest, and an object in motion will continue to move with a constant velocity, unless acted upon by an external force."
#
# In other words, an object will maintain its state of motion unless a force is applied to it.
#
# Let's consider an example:
#
# Imagine you're sitting in a car that's moving at a steady speed on the highway. You're not holding onto anything, and there are no obstacles or distractions inside the car.
#
# According to Newton's First Law, since there is no external force acting on you (no frictional forces from the seat or air resistance), you will continue to sit in your seat and maintain your state of rest (i.e., moving with a constant velocity).
#
# If the driver suddenly stops the car, you won't be thrown forward because there's no external force pushing you towards the front of the car. You'll simply remain in your seat, still moving at a steady speed.
#
# However, if the driver starts accelerating the car, say to take a curve or speed up, then an external force is applied to you (inertia), causing you to press back into your seat due to the changing motion.
#
# This law applies not just to objects on Earth but also to celestial bodies, like planets and stars, which continue to follow their orbits unless acted upon by external forces, such as gravity or collisions with other objects.
#
# Model: mistral:latest
# Memory before loading: 274.02 MB
# Memory after inference: 274.02 MB
# Memory used during inference: 0.00 MB
# Inference Time: 84.52 seconds
# Response:  Newton's First Law, also known as the Law of Inertia, states that an object at rest tends to stay at rest and an object in motion tends to stay in motion with the same speed and direction unless acted upon by an unbalanced force.
#
# In simpler terms, if there is no net force acting on an object, its state (either at rest or moving) will persist indefinitely. This is often referred to as "an object in motion stays in motion" or "a body at rest tends to stay at rest."
#
# Example: Suppose you are riding a bike down a hill. Once you let go of the brakes and start moving, you continue to move (assuming there are no external forces acting upon you) because you're applying a forward force by pedaling or rolling downhill. As long as there is no friction between your tires and the ground, or wind resistance, you will keep moving with the same speed in the same direction. If you stop pedaling, you would eventually come to a stop due to air resistance and other tiny forces acting on you, but for the time being, you'll maintain constant motion as long as there is no unbalanced force acting upon you.
#
# Model: llama3.1:latest
# Memory before loading: 274.02 MB
# Memory after inference: 274.02 MB
# Memory used during inference: 0.00 MB
# Inference Time: 157.71 seconds
# Response: Newton's First Law, also known as the Law of Inertia, states that:
#
# **An object at rest will remain at rest, and an object in motion will continue to move with a constant velocity, unless acted upon by an external force.**
#
# In other words, an object will maintain its state of motion (rest or movement) until a force is applied to it.
#
# Here's an example to illustrate this concept:
#
# **Example: A Car on a Flat Road**
#
# Imagine you're sitting in a car that's parked on a flat road. The car is at rest, with no external forces acting upon it. According to Newton's First Law, the car will remain at rest until something happens to change its motion.
#
# Now, let's say someone gets into the driver's seat and starts the engine. Suddenly, the car begins to move forward. This is an example of an external force (the engine) being applied to the car, causing it to accelerate from a state of rest to a state of motion.
#
# Next, imagine that you're driving on this flat road at a constant speed of 60 mph. As long as there are no external forces acting upon the car (e.g., friction, air resistance), the car will continue to move at a constant velocity of 60 mph, according to Newton's First Law.
#
# However, if someone slams on the brakes or you hit a patch of sand, the car's motion will be altered. The force applied by the brakes or the friction from the sand will slow down the car, causing it to change its state of motion.
#
# In summary, Newton's First Law states that an object at rest (like the parked car) will remain at rest until an external force is applied, and an object in motion (like the moving car) will continue to move with a constant velocity unless acted upon by an external force.
#
# Model: gemma2:2b
# Memory before loading: 274.02 MB
# Memory after inference: 274.02 MB
# Memory used during inference: 0.00 MB
# Inference Time: 18.98 seconds
# Response: ## Newton's First Law: Inertia
#
# **Newton's First Law of Motion**, also known as the **law of inertia**, states that an object at rest stays at rest and an object in motion stays in motion with the same speed and direction unless acted upon by an unbalanced force.
#
# **In simpler terms:** Objects like to keep doing what they're already doing. They don't want to change their state of rest or motion unless something pushes or pulls them.
#
# **Here's a classic example:**
#
# Imagine you have a book resting on a table. This book **is at rest**.  It'll stay there until someone pushes it, picks it up, or another force acts upon it (like gravity).  This resistance to change in motion is inertia.
#
# Now imagine a soccer ball rolling down the field. It's constantly in motion due to its initial push from your foot.  As long as no friction or external forces are acting on it, the ball will continue moving in a straight line at a constant speed. Even if it's slightly tilted, it'll roll that way until an opposing force like air resistance or hitting a wall changes its trajectory.
#
#
# **Key points:**
#
# * **Inertia:** An object's inertia is its tendency to resist change in motion. The heavier the object, the greater its inertia (think about how hard it takes to move a heavy box vs. a light one).
# * **Unbalanced force:**  When there is an unbalanced force acting on an object, it causes the object to accelerate or decelerate, changing its current state of rest or motion.
#
#
# Let me know if you'd like more examples or want to explore different aspects of Newton's laws! 😊

# %%
import os
import psutil
from time import time
# from ollama import Ollama

# List of models
models = [
    "llama3.2:1b",
    "llama3.2:3b",
    "mistral:latest",
    "llama3.1:latest",
    "gemma2:2b"
]

query = "Explain Newton's first law with an example."

def measure_memory_usage():
    """Returns detailed memory usage including RAM, Virtual memory, and swap."""
    process = psutil.Process(os.getpid())
    memory_info = process.memory_info()
    # Resident Set Size (RSS) is the memory used by the process in RAM
    rss_memory = memory_info.rss / (1024 ** 2)  # in MB
    vms_memory = memory_info.vms / (1024 ** 2)  # Virtual memory in MB
    swap_memory = psutil.swap_memory().used / (1024 ** 2)  # Swap memory in MB
    return rss_memory, vms_memory, swap_memory

def run_inference(model_name, query):
    """Load model, run inference, and measure memory usage."""
    llm = Ollama(model=model_name)
    
    # Measure memory usage before loading the model
    memory_before_rss, memory_before_vms, memory_before_swap = measure_memory_usage()
    
    # Perform inference
    start_time = time()
    response = llm(query)  # Perform the inference with the model
    inference_time = time() - start_time
    
    # Measure memory usage after inference
    memory_after_rss, memory_after_vms, memory_after_swap = measure_memory_usage()
    
    return {
        "memory_before_rss": memory_before_rss,
        "memory_before_vms": memory_before_vms,
        "memory_before_swap": memory_before_swap,
        "memory_after_rss": memory_after_rss,
        "memory_after_vms": memory_after_vms,
        "memory_after_swap": memory_after_swap,
        "inference_time": inference_time,
        "response": response
    }

# Loop through the models
for model_name in models:
    print(f"Model: {model_name}")
    
    # Run inference and measure memory usage
    results = run_inference(model_name, query)
    
    print(f"Memory before loading (RSS): {results['memory_before_rss']:.2f} MB")
    print(f"Memory before loading (Virtual Memory): {results['memory_before_vms']:.2f} MB")
    print(f"Memory before loading (Swap Memory): {results['memory_before_swap']:.2f} MB")
    
    print(f"Memory after inference (RSS): {results['memory_after_rss']:.2f} MB")
    print(f"Memory after inference (Virtual Memory): {results['memory_after_vms']:.2f} MB")
    print(f"Memory after inference (Swap Memory): {results['memory_after_swap']:.2f} MB")
    
    print(f"Inference Time: {results['inference_time']:.2f} seconds")
    print(f"Response: {results['response']}\n")
# Out:
# Model: llama3.2:1b
# Memory before loading (RSS): 274.03 MB
# Memory before loading (Virtual Memory): 502.02 MB
# Memory before loading (Swap Memory): 55.48 MB
# Memory after inference (RSS): 279.08 MB
# Memory after inference (Virtual Memory): 506.64 MB
# Memory after inference (Swap Memory): 55.48 MB
# Inference Time: 13.62 seconds
# Response: Newton's First Law of Motion, also known as the Law of Inertia, states that an object at rest will remain at rest, and an object in motion will continue to move with a constant velocity, unless acted upon by an external force.
#
# Here's an example to illustrate this concept:
#
# Imagine you're on a train, and you throw a ball straight up in the air. What happens? The ball comes down and lands in your hand, right?
#
# Now, let's say someone pushes you gently against the wall with their hands. What happens? The momentum of your body is transferred to the wall, causing it to move backward.
#
# In both cases, there was an external force (the person pushing or the train accelerating) that caused a change in motion. However, without any external force applied, the ball would have remained at rest in the air, and your body would have continued moving forward until you were pushed against the wall.
#
# This example demonstrates Newton's First Law of Motion: an object will maintain its state of motion unless acted upon by an external force. The train is at rest due to inertia (the tendency of the object to keep doing what it's already doing), and the person pushing against the wall is applying a force that changes your momentum, causing you to move backward.
#
# It's worth noting that Newton's First Law can be summarized as:
#
# * An object will remain in its state of motion unless acted upon by an external force.
# * The acceleration of an object is equal to the net force acting on it divided by its mass (F = ma).
#
# This law has numerous applications in various fields, including physics, engineering, and everyday life.
#
# Model: llama3.2:3b
# Memory before loading (RSS): 279.08 MB
# Memory before loading (Virtual Memory): 506.64 MB
# Memory before loading (Swap Memory): 55.48 MB
# Memory after inference (RSS): 279.08 MB
# Memory after inference (Virtual Memory): 506.64 MB
# Memory after inference (Swap Memory): 55.48 MB
# Inference Time: 15.00 seconds
# Response: Newton's First Law, also known as the Law of Inertia, states that:
#
# "An object at rest will remain at rest, and an object in motion will continue to move, unless acted upon by an external force."
#
# In simpler terms, if no external force is applied to an object, it will maintain its state of motion.
#
# Here's an example:
#
# Imagine you're sitting in a car on a straight road. The car is moving at a steady speed of 60 miles per hour. Suddenly, the driver brakes hard and comes to a complete stop. What happens next?
#
# According to Newton's First Law, since no external force was applied to the car (i.e., there was no friction from the brake pads), it will continue to move at its original speed until an external force acts upon it. In this case, the braking force applied by the driver is what slows down and eventually stops the car.
#
# So, if the car were not being driven and were left alone on the road, it would still be moving at 60 miles per hour indefinitely, since no external force was acting upon it to change its motion.
#
# Does that make sense?
#
# Model: mistral:latest
# Memory before loading (RSS): 279.08 MB
# Memory before loading (Virtual Memory): 506.64 MB
# Memory before loading (Swap Memory): 55.48 MB
# Memory after inference (RSS): 279.12 MB
# Memory after inference (Virtual Memory): 506.70 MB
# Memory after inference (Swap Memory): 55.48 MB
# Inference Time: 75.85 seconds
# Response:  Newton's First Law, also known as the Law of Inertia, states that an object at rest stays at rest and an object in motion stays in motion, unless acted upon by an unbalanced force. This means that if no net force acts on an object, its state of motion will remain constant.
#
# An example to illustrate this law is the classic case of a hockey puck sliding across an ice rink. Imagine you push a hockey puck with a gentle force, causing it to slide along the ice. Once you let go of the puck, it continues to move in a straight line at a constant speed because there are no external forces acting on it (assuming friction is negligible). This motion persists until another force acts upon it, such as air resistance or colliding with another object.
#
# In this example, the hockey puck at rest represents an object at rest, and it stays at rest due to the law of inertia. The hockey puck in motion represents an object in motion, and it continues moving due to the law of inertia until a net force acts upon it.
#
# Model: llama3.1:latest
# Memory before loading (RSS): 279.12 MB
# Memory before loading (Virtual Memory): 506.70 MB
# Memory before loading (Swap Memory): 55.48 MB
# Memory after inference (RSS): 279.09 MB
# Memory after inference (Virtual Memory): 506.64 MB
# Memory after inference (Swap Memory): 80.66 MB
# Inference Time: 115.87 seconds
# Response: Newton's First Law, also known as the Law of Inertia, states that:
#
# **An object at rest will remain at rest, and an object in motion will continue to move with a constant velocity, unless acted upon by an external force.**
#
# In other words, an object will maintain its state (rest or motion) until a force is applied to it.
#
# Here's an example to illustrate this law:
#
# **Example:** A car is parked on a flat road, not moving. The airbag and seatbelts are also off.
#
# Now, imagine you're sitting inside the car, feeling completely relaxed. Suddenly, someone slams the trunk of another car into yours, creating a strong impact. In this scenario:
#
# * **Before the collision**, the parked car was at rest (not moving).
# * **After the collision**, the parked car will continue to be at rest unless an external force (like the driver applying the brakes or accelerator) acts upon it.
#
# This example shows that the parked car, which was initially at rest, maintains its state (rest) until a force (the impact from another car) is applied to it. If no external force had acted on the parked car, it would have remained stationary forever!
#
# This concept illustrates Newton's First Law of motion in action.
#
# I hope this explanation helps! Let me know if you have any further questions.
#
# Model: gemma2:2b
# Memory before loading (RSS): 279.09 MB
# Memory before loading (Virtual Memory): 506.64 MB
# Memory before loading (Swap Memory): 80.66 MB
# Memory after inference (RSS): 279.09 MB
# Memory after inference (Virtual Memory): 506.64 MB
# Memory after inference (Swap Memory): 76.84 MB
# Inference Time: 18.56 seconds
# Response: ## Newton's First Law: Inertia Explained
#
# Newton's First Law of Motion states that **an object at rest stays at rest, and an object in motion stays in motion with the same speed and in the same direction unless acted upon by an unbalanced force.** This is also known as the law of inertia.
#
# **Think of it this way:**
#
# * Imagine a soccer ball sitting still on the ground. It will remain there until someone kicks it (applying a force).
# * Now imagine a bouncing basketball. It's constantly moving in any direction, and that motion continues until it encounters friction or another force to change its path.
#
#
# **Example: The Seatbelt**
#
# * You are driving down the highway at a constant speed of 60 mph.
#     * When your car suddenly brakes, you experience forward inertia because you're moving with a certain velocity and your body wants to continue that motion (Newton’s first law).
#     *  A seatbelt comes into play by applying an *unbalanced force* against your body - opposing the natural tendency of your body to go forward. This allows the car to slow down, and you don't crash into the dashboard or windshield as you continue to travel forward.
#
#
# **Key Points:**
#
# * **Inertia**: The tendency of a body to resist changes in its state of motion (rest or movement).
# * **Unbalanced Force**: Any force that creates a change in an object’s motion, either by causing it to stop or start moving, or changing its speed or direction.
#
#
# **In Summary:**
#
# Newton's First Law explains why things tend to stay still or keep moving at a constant velocity unless acted upon by an external force.

# %%
import time

# Assuming llm_model is already defined
# List of models
models = [
    "llama3.2:1b",
    "llama3.2:3b",
    "mistral:latest",
    "llama3.1:latest",
    "gemma2:2b"
]

query = "Explain Newton's first law with an example."

# Function to calculate token generation speed
def token_generation_speed(model, query):
    start_time = time.time()
    response = model(query)  # Call the model's inference method
    end_time = time.time()
    tokens = len(response.split())  # Assuming token == word; use proper tokenization if needed
    time_taken = end_time - start_time
    return tokens / time_taken

# Loop through the models and measure token generation speed for each
for model_name in models:
    print(f"Model: {model_name}")
    
    # Load the model
    llm = Ollama(model=model_name)
    
    # Calculate token generation speed
    speed = token_generation_speed(llm, query)
    print(f"Token Generation Speed: {speed:.2f} tokens/sec\n")
# Out:
# Model: llama3.2:1b
# Token Generation Speed: 21.83 tokens/sec
#
# Model: llama3.2:3b
# Token Generation Speed: 13.01 tokens/sec
#
# Model: mistral:latest
# Token Generation Speed: 2.56 tokens/sec
#
# Model: llama3.1:latest
# Token Generation Speed: 1.90 tokens/sec
#
# Model: gemma2:2b
# Token Generation Speed: 14.58 tokens/sec
